# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 601

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = f'https://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}' # YOUR CODE HERE

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f'https://api.openweathermap.org/data/2.5/weather?q={city}&appid={weather_api_key}&units=metric' # YOUR CODE HERE

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json() # YOUR CODE HERE

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat'] # YOUR CODE HERE
        city_lng = city_weather['coord']['lon'] # YOUR CODE HERE
        city_max_temp = city_weather['main']['temp_max'] # YOUR CODE HERE
        city_humidity = city_weather['main']['humidity'] # YOUR CODE HERE
        city_clouds = city_weather['clouds']['all'] # YOUR CODE HERE
        city_wind = city_weather['wind']['speed'] # YOUR CODE HERE
        city_country = city_weather['sys']['country']# YOUR CODE HERE
        city_date = city_weather['dt'] # YOUR CODE HERE

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | amga
# Processing Record 2 of Set 1 | scottburgh
# Processing Record 3 of Set 1 | adamstown
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | iskateley
# Processing Record 6 of Set 1 | puerto ayora
# Processing Record 7 of Set 1 | qaqortoq
# Processing Record 8 of Set 1 | puerto armuelles
# Processing Record 9 of Set 1 | anadyr
# Processing Record 10 of Set 1 | xilin hot
# Processing Record 11 of Set 1 | zaprudnya
# Processing Record 12 of Set 1 | sao gabriel da cachoeira
# Processing Record 13 of Set 1 | udachny
# Processing Record 14 of Set 1 | crane
# Processing Record 15 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 16 of Set 1 | betioky
# Processing Record 17 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 18 of Set 1 | puerto deseado
# Processing Record 19 of Set 1 | west island
# Processing Record 20 of Set 1 | waitangi
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | ribeira grande
# Processing Record 23 of Set 1 | namibe
# Processing Record 24 of Set 1 | moyynkum
# Processing Record 25 of Set 1 | puerto natales
# Processing Record 26 of Set 1 | hermanus
# Processing Record 27 of Set 1 | kingston
# Processing Record 28 of Set 1 | nemuro
# Processing Record 29 of Set 1 | yellowknife
# Processing Record 30 of Set 1 | tobati
# Processing Record 31 of Set 1 | kyaikto
# Processing Record 32 of Set 1 | flying fish cove
# Processing Record 33 of Set 1 | mount gambier
# Processing Record 34 of Set 1 | wailua homesteads
# Processing Record 35 of Set 1 | bardai
# Processing Record 36 of Set 1 | palpa
# Processing Record 37 of Set 1 | conduaga
# Processing Record 38 of Set 1 | tupiza
# Processing Record 39 of Set 1 | margaret river
# Processing Record 40 of Set 1 | usinsk
# Processing Record 41 of Set 1 | vingt cinq
# City not found. Skipping...
# Processing Record 42 of Set 1 | hawaiian paradise park
# Processing Record 43 of Set 1 | margate
# Processing Record 44 of Set 1 | holualoa
# Processing Record 45 of Set 1 | port-aux-francais
# Processing Record 46 of Set 1 | blackmans bay
# Processing Record 47 of Set 1 | carlos chagas
# Processing Record 48 of Set 1 | port shepstone
# Processing Record 49 of Set 1 | san julian
# Processing Record 50 of Set 1 | saint-francois
# Processing Record 0 of Set 2 | villa regina
# Processing Record 1 of Set 2 | nova vicosa
# Processing Record 2 of Set 2 | hithadhoo
# Processing Record 3 of Set 2 | bilibino
# Processing Record 4 of Set 2 | bamboo flat
# Processing Record 5 of Set 2 | olonkinbyen
# Processing Record 6 of Set 2 | isafjordur
# Processing Record 7 of Set 2 | antsiranana
# Processing Record 8 of Set 2 | malanje
# Processing Record 9 of Set 2 | ancud
# Processing Record 10 of Set 2 | krasnyy kholm
# Processing Record 11 of Set 2 | kerikeri
# Processing Record 12 of Set 2 | takamaka
# City not found. Skipping...
# Processing Record 13 of Set 2 | hamilton
# Processing Record 14 of Set 2 | fale old settlement
# Processing Record 15 of Set 2 | otjiwarongo
# Processing Record 16 of Set 2 | stanley
# Processing Record 17 of Set 2 | iqaluit
# Processing Record 18 of Set 2 | talnakh
# Processing Record 19 of Set 2 | mugia
# Processing Record 20 of Set 2 | inhambane
# Processing Record 21 of Set 2 | avarua
# Processing Record 22 of Set 2 | northam
# Processing Record 23 of Set 2 | badger
# Processing Record 24 of Set 2 | pokaran
# Processing Record 25 of Set 2 | north battleford
# Processing Record 26 of Set 2 | thompson
# Processing Record 27 of Set 2 | prince rupert
# Processing Record 28 of Set 2 | arraial do cabo
# Processing Record 29 of Set 2 | yuzhno-kurilsk
# Processing Record 30 of Set 2 | yigo village
# Processing Record 31 of Set 2 | mutuali
# Processing Record 32 of Set 2 | georgetown
# Processing Record 33 of Set 2 | gamba
# Processing Record 34 of Set 2 | grytviken
# Processing Record 35 of Set 2 | bol
# Processing Record 36 of Set 2 | outapi
# City not found. Skipping...
# Processing Record 37 of Set 2 | nova olinda do norte
# Processing Record 38 of Set 2 | dudinka
# Processing Record 39 of Set 2 | afaahiti
# Processing Record 40 of Set 2 | tura
# Processing Record 41 of Set 2 | vadso
# Processing Record 42 of Set 2 | tranovaho
# City not found. Skipping...
# Processing Record 43 of Set 2 | huocheng
# City not found. Skipping...
# Processing Record 44 of Set 2 | malango
# Processing Record 45 of Set 2 | as sulayyil
# Processing Record 46 of Set 2 | ust-nera
# Processing Record 47 of Set 2 | san antonio de pale
# Processing Record 48 of Set 2 | whitehorse
# Processing Record 49 of Set 2 | port mathurin
# Processing Record 0 of Set 3 | cadale
# Processing Record 1 of Set 3 | kismayo
# Processing Record 2 of Set 3 | tikaitnagar
# Processing Record 3 of Set 3 | puerto san carlos
# City not found. Skipping...
# Processing Record 4 of Set 3 | pont rouge
# Processing Record 5 of Set 3 | tiksi
# Processing Record 6 of Set 3 | jamestown
# Processing Record 7 of Set 3 | lesnoy
# Processing Record 8 of Set 3 | whangarei
# Processing Record 9 of Set 3 | bethel
# Processing Record 10 of Set 3 | morondava
# Processing Record 11 of Set 3 | adrar
# Processing Record 12 of Set 3 | punta arenas
# Processing Record 13 of Set 3 | sodra sandby
# Processing Record 14 of Set 3 | fuvahmulah
# City not found. Skipping...
# Processing Record 15 of Set 3 | mermoz boabab
# Processing Record 16 of Set 3 | santa terezinha
# Processing Record 17 of Set 3 | chibougamau
# Processing Record 18 of Set 3 | akureyri
# Processing Record 19 of Set 3 | el bauga
# Processing Record 20 of Set 3 | baoding
# Processing Record 21 of Set 3 | businga
# Processing Record 22 of Set 3 | loango
# Processing Record 23 of Set 3 | longyearbyen
# Processing Record 24 of Set 3 | nikel
# Processing Record 25 of Set 3 | mount isa
# Processing Record 26 of Set 3 | invercargill
# Processing Record 27 of Set 3 | kununurra
# Processing Record 28 of Set 3 | susuman
# Processing Record 29 of Set 3 | fuerte olimpo
# Processing Record 30 of Set 3 | pemangkat
# Processing Record 31 of Set 3 | mejit
# Processing Record 32 of Set 3 | okha
# Processing Record 33 of Set 3 | borogontsy
# Processing Record 34 of Set 3 | quepos
# Processing Record 35 of Set 3 | atafu village
# Processing Record 36 of Set 3 | thinadhoo
# Processing Record 37 of Set 3 | svitlovods'k
# Processing Record 38 of Set 3 | el charco
# Processing Record 39 of Set 3 | labrador city
# Processing Record 40 of Set 3 | huarmey
# Processing Record 41 of Set 3 | edinburgh of the seven seas
# Processing Record 42 of Set 3 | opuwo
# Processing Record 43 of Set 3 | daru
# Processing Record 44 of Set 3 | nova sintra
# Processing Record 45 of Set 3 | tazovsky
# Processing Record 46 of Set 3 | kidal
# Processing Record 47 of Set 3 | fisterra
# Processing Record 48 of Set 3 | novaya igirma
# Processing Record 49 of Set 3 | tommot
# Processing Record 0 of Set 4 | rasht
# Processing Record 1 of Set 4 | airdrie
# Processing Record 2 of Set 4 | codrington
# Processing Record 3 of Set 4 | kralendijk
# Processing Record 4 of Set 4 | lorengau
# Processing Record 5 of Set 4 | la passe
# Processing Record 6 of Set 4 | port elizabeth
# Processing Record 7 of Set 4 | tolanaro
# Processing Record 8 of Set 4 | vuktyl
# Processing Record 9 of Set 4 | nabire
# Processing Record 10 of Set 4 | maevatanana
# Processing Record 11 of Set 4 | port lincoln
# Processing Record 12 of Set 4 | liberty lake
# Processing Record 13 of Set 4 | st. john's
# Processing Record 14 of Set 4 | perry
# Processing Record 15 of Set 4 | sambava
# Processing Record 16 of Set 4 | ibi
# Processing Record 17 of Set 4 | constantia
# Processing Record 18 of Set 4 | kodiak
# Processing Record 19 of Set 4 | khandyga
# Processing Record 20 of Set 4 | undurkhaan
# Processing Record 21 of Set 4 | saipan
# Processing Record 22 of Set 4 | devinuwara
# City not found. Skipping...
# Processing Record 23 of Set 4 | rongelap
# Processing Record 24 of Set 4 | papatowai
# Processing Record 25 of Set 4 | alesund
# Processing Record 26 of Set 4 | vila velha
# Processing Record 27 of Set 4 | satipo
# Processing Record 28 of Set 4 | apatity
# Processing Record 29 of Set 4 | el golaa
# Processing Record 30 of Set 4 | karaj
# Processing Record 31 of Set 4 | taltal
# Processing Record 32 of Set 4 | niafunke
# Processing Record 33 of Set 4 | ust'-barguzin
# Processing Record 34 of Set 4 | wainwright
# Processing Record 35 of Set 4 | katsuura
# Processing Record 36 of Set 4 | port glaud
# City not found. Skipping...
# Processing Record 37 of Set 4 | sisimiut
# Processing Record 38 of Set 4 | oriximina
# Processing Record 39 of Set 4 | rattvik
# City not found. Skipping...
# Processing Record 40 of Set 4 | vila franca do campo
# Processing Record 41 of Set 4 | coahuayana de hidalgo
# Processing Record 42 of Set 4 | alotau
# Processing Record 43 of Set 4 | keminmaa
# Processing Record 44 of Set 4 | kone
# Processing Record 45 of Set 4 | faya-largeau
# Processing Record 46 of Set 4 | new norfolk
# Processing Record 47 of Set 4 | chonchi
# Processing Record 48 of Set 4 | kourou
# Processing Record 49 of Set 4 | i-n-salah
# Processing Record 0 of Set 5 | palikir - national government center
# Processing Record 1 of Set 5 | klyuchi
# Processing Record 2 of Set 5 | al kharijah
# Processing Record 3 of Set 5 | brookings
# Processing Record 4 of Set 5 | aasiaat
# Processing Record 5 of Set 5 | ilulissat
# Processing Record 6 of Set 5 | lompoc
# Processing Record 7 of Set 5 | konarka
# Processing Record 8 of Set 5 | ignalina
# Processing Record 9 of Set 5 | goalpara
# Processing Record 10 of Set 5 | watertown
# Processing Record 11 of Set 5 | lionel town
# Processing Record 12 of Set 5 | san jose del guaviare
# Processing Record 13 of Set 5 | nagqu
# Processing Record 14 of Set 5 | enoch
# Processing Record 15 of Set 5 | raja
# Processing Record 16 of Set 5 | rawai
# Processing Record 17 of Set 5 | minas de marcona
# Processing Record 18 of Set 5 | uturoa
# Processing Record 19 of Set 5 | tongouson
# Processing Record 20 of Set 5 | saint-philippe
# Processing Record 21 of Set 5 | richards bay
# Processing Record 22 of Set 5 | villarrica
# Processing Record 23 of Set 5 | san patricio
# Processing Record 24 of Set 5 | grand falls-windsor
# Processing Record 25 of Set 5 | soure
# Processing Record 26 of Set 5 | galle
# Processing Record 27 of Set 5 | itoman
# Processing Record 28 of Set 5 | ambodifotatra
# Processing Record 29 of Set 5 | cable beach
# City not found. Skipping...
# Processing Record 30 of Set 5 | broome
# Processing Record 31 of Set 5 | peace river
# Processing Record 32 of Set 5 | talcahuano
# Processing Record 33 of Set 5 | hiratacho
# Processing Record 34 of Set 5 | tshikapa
# Processing Record 35 of Set 5 | benalla
# Processing Record 36 of Set 5 | sangmelima
# Processing Record 37 of Set 5 | utrik
# Processing Record 38 of Set 5 | alice springs
# Processing Record 39 of Set 5 | maxixe
# Processing Record 40 of Set 5 | selma
# Processing Record 41 of Set 5 | revda
# Processing Record 42 of Set 5 | greenville
# Processing Record 43 of Set 5 | shumikha
# Processing Record 44 of Set 5 | kakanj
# Processing Record 45 of Set 5 | ust'-talovka
# Processing Record 46 of Set 5 | bredasdorp
# Processing Record 47 of Set 5 | riesi
# Processing Record 48 of Set 5 | igarka
# Processing Record 49 of Set 5 | selkirk
# Processing Record 0 of Set 6 | vorgashor
# Processing Record 1 of Set 6 | vallenar
# Processing Record 2 of Set 6 | santiago
# Processing Record 3 of Set 6 | galliano
# Processing Record 4 of Set 6 | constitucion
# Processing Record 5 of Set 6 | north cowichan
# Processing Record 6 of Set 6 | buabidi
# City not found. Skipping...
# Processing Record 7 of Set 6 | aras-asan
# Processing Record 8 of Set 6 | howrah
# Processing Record 9 of Set 6 | kodinsk
# Processing Record 10 of Set 6 | yajiwa
# Processing Record 11 of Set 6 | lai chau
# Processing Record 12 of Set 6 | kaitong
# Processing Record 13 of Set 6 | rudsar
# Processing Record 14 of Set 6 | huanuco
# Processing Record 15 of Set 6 | arkhangel'sk
# Processing Record 16 of Set 6 | 'ohonua
# City not found. Skipping...
# Processing Record 17 of Set 6 | bluefields
# Processing Record 18 of Set 6 | chinde
# Processing Record 19 of Set 6 | carnarvon
# Processing Record 20 of Set 6 | nicoya
# Processing Record 21 of Set 6 | klaksvik
# Processing Record 22 of Set 6 | bayanhongor
# Processing Record 23 of Set 6 | wenling
# Processing Record 24 of Set 6 | san carlos
# Processing Record 25 of Set 6 | darhan
# Processing Record 26 of Set 6 | moorhead
# Processing Record 27 of Set 6 | eirunepe
# Processing Record 28 of Set 6 | haiku-pauwela
# Processing Record 29 of Set 6 | darwin
# Processing Record 30 of Set 6 | kirkwood
# Processing Record 31 of Set 6 | portland
# Processing Record 32 of Set 6 | chimbarongo
# Processing Record 33 of Set 6 | les anglais
# Processing Record 34 of Set 6 | selfoss
# Processing Record 35 of Set 6 | ad dabbah
# Processing Record 36 of Set 6 | usogorsk
# Processing Record 37 of Set 6 | pierre
# Processing Record 38 of Set 6 | saldanha
# Processing Record 39 of Set 6 | halifax
# Processing Record 40 of Set 6 | pacific grove
# Processing Record 41 of Set 6 | sarangani
# Processing Record 42 of Set 6 | champerico
# Processing Record 43 of Set 6 | enewetak
# Processing Record 44 of Set 6 | yagunovskiy
# Processing Record 45 of Set 6 | ain sefra
# Processing Record 46 of Set 6 | menongue
# Processing Record 47 of Set 6 | hadibu
# Processing Record 48 of Set 6 | solikamsk
# Processing Record 49 of Set 6 | ponta delgada
# Processing Record 0 of Set 7 | douentza
# Processing Record 1 of Set 7 | anamur
# Processing Record 2 of Set 7 | mata-utu
# Processing Record 3 of Set 7 | teguise
# Processing Record 4 of Set 7 | protvino
# Processing Record 5 of Set 7 | yeppoon
# Processing Record 6 of Set 7 | aldama
# Processing Record 7 of Set 7 | cabo san lucas
# Processing Record 8 of Set 7 | wenchang
# Processing Record 9 of Set 7 | likiep
# Processing Record 10 of Set 7 | mormugao
# Processing Record 11 of Set 7 | soio
# Processing Record 12 of Set 7 | bununu
# Processing Record 13 of Set 7 | lerwick
# Processing Record 14 of Set 7 | hilo
# Processing Record 15 of Set 7 | den burg
# Processing Record 16 of Set 7 | chegdomyn
# Processing Record 17 of Set 7 | chul'man
# Processing Record 18 of Set 7 | sant'antioco
# Processing Record 19 of Set 7 | coruripe
# Processing Record 20 of Set 7 | al jabin
# Processing Record 21 of Set 7 | broken hill
# Processing Record 22 of Set 7 | arar
# Processing Record 23 of Set 7 | callao
# Processing Record 24 of Set 7 | turaif
# Processing Record 25 of Set 7 | papao
# Processing Record 26 of Set 7 | roses
# Processing Record 27 of Set 7 | celestun
# Processing Record 28 of Set 7 | taoudenni
# Processing Record 29 of Set 7 | xining
# Processing Record 30 of Set 7 | mao
# Processing Record 31 of Set 7 | new kingman-butler
# Processing Record 32 of Set 7 | ujae
# Processing Record 33 of Set 7 | freetown
# Processing Record 34 of Set 7 | coquimbo
# Processing Record 35 of Set 7 | srandakan
# Processing Record 36 of Set 7 | uzhur
# Processing Record 37 of Set 7 | caleta de carquin
# Processing Record 38 of Set 7 | okhotsk
# Processing Record 39 of Set 7 | nongstoin
# Processing Record 40 of Set 7 | ostersund
# Processing Record 41 of Set 7 | ta`u
# Processing Record 42 of Set 7 | lebu
# Processing Record 43 of Set 7 | hailar
# Processing Record 44 of Set 7 | euclides da cunha
# Processing Record 45 of Set 7 | mansa
# Processing Record 46 of Set 7 | gobabis
# Processing Record 47 of Set 7 | shihezi
# Processing Record 48 of Set 7 | augustow
# Processing Record 49 of Set 7 | huicungo
# Processing Record 0 of Set 8 | ixtapa
# Processing Record 1 of Set 8 | bokovskaya
# Processing Record 2 of Set 8 | isangel
# Processing Record 3 of Set 8 | harper
# Processing Record 4 of Set 8 | port augusta
# Processing Record 5 of Set 8 | tazacorte
# Processing Record 6 of Set 8 | ahau
# City not found. Skipping...
# Processing Record 7 of Set 8 | fonadhoo
# City not found. Skipping...
# Processing Record 8 of Set 8 | sinabang
# Processing Record 9 of Set 8 | marquette
# Processing Record 10 of Set 8 | atamyrat
# Processing Record 11 of Set 8 | las toscas
# Processing Record 12 of Set 8 | than
# Processing Record 13 of Set 8 | markovo
# Processing Record 14 of Set 8 | tobi village
# City not found. Skipping...
# Processing Record 15 of Set 8 | urengoy
# Processing Record 16 of Set 8 | la ronge
# Processing Record 17 of Set 8 | dubbo
# Processing Record 18 of Set 8 | sandnessjoen
# Processing Record 19 of Set 8 | nar'yan-mar
# Processing Record 20 of Set 8 | angarsk
# Processing Record 21 of Set 8 | agat village
# Processing Record 22 of Set 8 | parepare
# City not found. Skipping...
# Processing Record 23 of Set 8 | trincomalee
# Processing Record 24 of Set 8 | pitea
# Processing Record 25 of Set 8 | deming
# Processing Record 26 of Set 8 | colonia
# Processing Record 27 of Set 8 | twentynine palms
# Processing Record 28 of Set 8 | elliot
# Processing Record 29 of Set 8 | krasnovishersk
# Processing Record 30 of Set 8 | ulladulla
# Processing Record 31 of Set 8 | keelung
# Processing Record 32 of Set 8 | san salvador de jujuy
# Processing Record 33 of Set 8 | holmen
# Processing Record 34 of Set 8 | betio village
# Processing Record 35 of Set 8 | arrifes
# Processing Record 36 of Set 8 | dar naim
# City not found. Skipping...
# Processing Record 37 of Set 8 | zhob
# Processing Record 38 of Set 8 | hancheng
# Processing Record 39 of Set 8 | lagunas
# Processing Record 40 of Set 8 | mo i rana
# Processing Record 41 of Set 8 | ribeira brava
# Processing Record 42 of Set 8 | mahina
# Processing Record 43 of Set 8 | hotan
# Processing Record 44 of Set 8 | luderitz
# Processing Record 45 of Set 8 | newman
# Processing Record 46 of Set 8 | suntar
# Processing Record 47 of Set 8 | palmer
# Processing Record 48 of Set 8 | tongliao
# Processing Record 49 of Set 8 | keflavik
# Processing Record 0 of Set 9 | borovskoy
# Processing Record 1 of Set 9 | vanino
# Processing Record 2 of Set 9 | rio claro
# Processing Record 3 of Set 9 | divnogorsk
# Processing Record 4 of Set 9 | truckee
# Processing Record 5 of Set 9 | hami
# Processing Record 6 of Set 9 | bonthe
# Processing Record 7 of Set 9 | tsiombe
# Processing Record 8 of Set 9 | manokwari
# Processing Record 9 of Set 9 | arteche
# Processing Record 10 of Set 9 | priozersk
# Processing Record 11 of Set 9 | ketchikan
# Processing Record 12 of Set 9 | fuxin
# Processing Record 13 of Set 9 | talavera
# Processing Record 14 of Set 9 | itabira
# Processing Record 15 of Set 9 | ocos
# Processing Record 16 of Set 9 | east london
# Processing Record 17 of Set 9 | alappuzha
# Processing Record 18 of Set 9 | port alfred
# Processing Record 19 of Set 9 | bathsheba
# Processing Record 20 of Set 9 | naze
# Processing Record 21 of Set 9 | tanjungtiram
# Processing Record 22 of Set 9 | balaipungut
# Processing Record 23 of Set 9 | tadine
# Processing Record 24 of Set 9 | qashar
# Processing Record 25 of Set 9 | strathalbyn
# Processing Record 26 of Set 9 | namsos
# Processing Record 27 of Set 9 | paramonga
# Processing Record 28 of Set 9 | tofol
# Processing Record 29 of Set 9 | porbandar
# Processing Record 30 of Set 9 | pastos bons
# Processing Record 31 of Set 9 | kavieng
# Processing Record 32 of Set 9 | katsuren-haebaru
# Processing Record 33 of Set 9 | kencong
# Processing Record 34 of Set 9 | tinajo
# Processing Record 35 of Set 9 | twon-brass
# Processing Record 36 of Set 9 | qarazhal
# Processing Record 37 of Set 9 | talara
# Processing Record 38 of Set 9 | tekeli
# Processing Record 39 of Set 9 | serdar
# Processing Record 40 of Set 9 | puerto san jose
# Processing Record 41 of Set 9 | villa nueva
# Processing Record 42 of Set 9 | dunn
# Processing Record 43 of Set 9 | remire-montjoly
# Processing Record 44 of Set 9 | makhambet
# Processing Record 45 of Set 9 | sao benedito do rio preto
# Processing Record 46 of Set 9 | da nang
# Processing Record 47 of Set 9 | corralillo
# Processing Record 48 of Set 9 | severo-yeniseyskiy
# Processing Record 49 of Set 9 | sao tome
# Processing Record 0 of Set 10 | santa marta de ortigueira
# Processing Record 1 of Set 10 | pimenta bueno
# Processing Record 2 of Set 10 | praia da vitoria
# Processing Record 3 of Set 10 | ouadda
# Processing Record 4 of Set 10 | zacualtipan
# Processing Record 5 of Set 10 | college
# Processing Record 6 of Set 10 | belo sur tsiribihina
# Processing Record 7 of Set 10 | isla mujeres
# Processing Record 8 of Set 10 | chutove
# Processing Record 9 of Set 10 | akjoujt
# Processing Record 10 of Set 10 | gaalkacyo
# Processing Record 11 of Set 10 | ovalle
# Processing Record 12 of Set 10 | aitape
# Processing Record 13 of Set 10 | pangody
# Processing Record 14 of Set 10 | rio grande
# Processing Record 15 of Set 10 | badiyah
# Processing Record 16 of Set 10 | bilozerka
# Processing Record 17 of Set 10 | dunedin
# Processing Record 18 of Set 10 | pathein
# Processing Record 19 of Set 10 | bocsa
# Processing Record 20 of Set 10 | noshiro
# Processing Record 21 of Set 10 | kovdor
# Processing Record 22 of Set 10 | benemerito de las americas
# Processing Record 23 of Set 10 | cukai
# Processing Record 24 of Set 10 | olgii
# City not found. Skipping...
# Processing Record 25 of Set 10 | san andres
# Processing Record 26 of Set 10 | sarlat-la-caneda
# Processing Record 27 of Set 10 | palafrugell
# Processing Record 28 of Set 10 | happy valley-goose bay
# Processing Record 29 of Set 10 | santiago papasquiaro
# Processing Record 30 of Set 10 | turuntayevo
# Processing Record 31 of Set 10 | tralee
# Processing Record 32 of Set 10 | massawa
# Processing Record 33 of Set 10 | juan de herrera
# Processing Record 34 of Set 10 | sodankyla
# Processing Record 35 of Set 10 | alofi
# Processing Record 36 of Set 10 | tucano
# Processing Record 37 of Set 10 | ocean pointe
# City not found. Skipping...
# Processing Record 38 of Set 10 | alpine
# Processing Record 39 of Set 10 | burang
# Processing Record 40 of Set 10 | dongola
# Processing Record 41 of Set 10 | roma
# Processing Record 42 of Set 10 | sydney mines
# Processing Record 43 of Set 10 | laojunmiao
# Processing Record 44 of Set 10 | greymouth
# Processing Record 45 of Set 10 | maragogi
# Processing Record 46 of Set 10 | ola
# Processing Record 47 of Set 10 | sandakan
# Processing Record 48 of Set 10 | inekar
# City not found. Skipping...
# Processing Record 49 of Set 10 | fosses
# Processing Record 0 of Set 11 | baduria
# Processing Record 1 of Set 11 | praya
# Processing Record 2 of Set 11 | bukan
# Processing Record 3 of Set 11 | tlacotepec
# Processing Record 4 of Set 11 | horta
# Processing Record 5 of Set 11 | laguna
# Processing Record 6 of Set 11 | otuzco
# Processing Record 7 of Set 11 | baldev
# Processing Record 8 of Set 11 | santa cruz
# Processing Record 9 of Set 11 | gandi
# Processing Record 10 of Set 11 | floro
# Processing Record 11 of Set 11 | sergeyevka
# Processing Record 12 of Set 11 | iquique
# Processing Record 13 of Set 11 | cockburn town
# Processing Record 14 of Set 11 | lagoa
# Processing Record 15 of Set 11 | port blair
# Processing Record 16 of Set 11 | ishigaki
# Processing Record 17 of Set 11 | al mutayrifi
# Processing Record 18 of Set 11 | rawson
# Processing Record 19 of Set 11 | namtsy
# Processing Record 20 of Set 11 | timimoun
# Processing Record 21 of Set 11 | asau
# Processing Record 22 of Set 11 | natchez
# Processing Record 23 of Set 11 | fortuna
# Processing Record 24 of Set 11 | weno
# Processing Record 25 of Set 11 | annau
# Processing Record 26 of Set 11 | barra de santo antonio
# Processing Record 27 of Set 11 | rosarito
# Processing Record 28 of Set 11 | chernyshevskiy
# Processing Record 29 of Set 11 | fuglafjordur
# Processing Record 30 of Set 11 | ghat
# Processing Record 31 of Set 11 | bayan nur
# City not found. Skipping...
# Processing Record 32 of Set 11 | skovorodino
# Processing Record 33 of Set 11 | dalby
# Processing Record 34 of Set 11 | piton saint-leu
# Processing Record 35 of Set 11 | mirpur sakro
# Processing Record 36 of Set 11 | monterey
# Processing Record 37 of Set 11 | kuta
# Processing Record 38 of Set 11 | oulunsalo
# Processing Record 39 of Set 11 | morehead city
# Processing Record 40 of Set 11 | vernon
# Processing Record 41 of Set 11 | bikenibeu village
# Processing Record 42 of Set 11 | kavaratti
# Processing Record 43 of Set 11 | ba
# City not found. Skipping...
# Processing Record 44 of Set 11 | rakops
# Processing Record 45 of Set 11 | egilsstadir
# Processing Record 46 of Set 11 | wake village
# Processing Record 47 of Set 11 | al bardiyah
# Processing Record 48 of Set 11 | akoupe
# Processing Record 49 of Set 11 | quebo
# Processing Record 0 of Set 12 | takab
# Processing Record 1 of Set 12 | baglung
# Processing Record 2 of Set 12 | mukalla
# Processing Record 3 of Set 12 | sabratah
# Processing Record 4 of Set 12 | masterton
# Processing Record 5 of Set 12 | fiambala
# Processing Record 6 of Set 12 | lucapa
# Processing Record 7 of Set 12 | zhuanghe
# Processing Record 8 of Set 12 | governor's harbour
# City not found. Skipping...
# Processing Record 9 of Set 12 | khurai
# Processing Record 10 of Set 12 | prince george
# Processing Record 11 of Set 12 | fada
# Processing Record 12 of Set 12 | kalemie
# Processing Record 13 of Set 12 | mthatha
# Processing Record 14 of Set 12 | pikalevo
# Processing Record 15 of Set 12 | aktau
# Processing Record 16 of Set 12 | zhezqazghan
# Processing Record 17 of Set 12 | jalai nur
# Processing Record 18 of Set 12 | nova xavantina
# Processing Record 19 of Set 12 | colipapa
# Processing Record 20 of Set 12 | acapulco de juarez
# Processing Record 21 of Set 12 | terrace
# Processing Record 22 of Set 12 | al ghayzah
# Processing Record 23 of Set 12 | cayeli
# Processing Record 24 of Set 12 | tanout
# Processing Record 25 of Set 12 | sitka
# Processing Record 26 of Set 12 | dalandzadgad
# Processing Record 27 of Set 12 | novyy urgal
# Processing Record 28 of Set 12 | calbayog city
# Processing Record 29 of Set 12 | sebastopol
# Processing Record 30 of Set 12 | frenda
# Processing Record 31 of Set 12 | mahibadhoo
# Processing Record 32 of Set 12 | orapa
# Processing Record 33 of Set 12 | bure
# Processing Record 34 of Set 12 | labytnangi
# Processing Record 35 of Set 12 | felidhoo
# City not found. Skipping...
# Processing Record 36 of Set 12 | oulainen
# Processing Record 37 of Set 12 | nyurba
# Processing Record 38 of Set 12 | salinas
# Processing Record 39 of Set 12 | port isabel
# Processing Record 40 of Set 12 | lampazos de naranjo
# Processing Record 41 of Set 12 | ballina
# Processing Record 42 of Set 12 | guaruja
# Processing Record 43 of Set 12 | san luis de la loma
# Processing Record 44 of Set 12 | gwadar
# Processing Record 45 of Set 12 | nouadhibou
# Processing Record 46 of Set 12 | gagliano del capo
# Processing Record 47 of Set 12 | la'ie
# Processing Record 48 of Set 12 | kapuskasing
# Processing Record 49 of Set 12 | hun
# Processing Record 0 of Set 13 | obernkirchen
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data) # YOUR CODE HERE
city_data_df['Date'] = pd.to_datetime(city_data_df['Date'], unit='s')
# Show Record Count
city_data_df.count()
# Out:
# City          575
# Lat           575
# Lng           575
# Max Temp      575
# Humidity      575
# Cloudiness    575
# Wind Speed    575
# Country       575
# Date          575
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        amga  60.8953  131.9608     15.66        84          71        2.46
# 1  scottburgh -30.2867   30.7532     14.88        74           0        2.28
# 2   adamstown -25.0660 -130.1015     18.70        66          39        5.08
# 3      albany  42.6001  -73.9662     18.50        80         100        1.72
# 4   iskateley  67.6803   53.1512     10.28        64           8        2.95
#
#   Country                Date
# 0      RU 2024-08-07 02:28:52
# 1      ZA 2024-08-07 02:33:19
# 2      PN 2024-08-07 02:28:51
# 3      US 2024-08-07 02:22:50
# 4      RU 2024-08-07 02:33:23

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0              amga  60.8953  131.9608     15.66        84          71
# 1        scottburgh -30.2867   30.7532     14.88        74           0
# 2         adamstown -25.0660 -130.1015     18.70        66          39
# 3            albany  42.6001  -73.9662     18.50        80         100
# 4         iskateley  67.6803   53.1512     10.28        64           8
#
#          Wind Speed Country                 Date
# City_ID
# 0              2.46      RU  2024-08-07 02:28:52
# 1              2.28      ZA  2024-08-07 02:33:19
# 2              5.08      PN  2024-08-07 02:28:51
# 3              1.72      US  2024-08-07 02:22:50
# 4              2.95      RU  2024-08-07 02:33:23

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'],city_data_df['Max Temp'], marker='o', facecolors='b', edgecolors='k')# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# date = city_data_df['Date'].min().strftime('%Y-%m-%d')

plt.grid(False)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature °C")
date = city_data_df['Date'].min()
plt.title(f"City Latitude vs. Temperature ({date})")
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
city_data_df.plot(kind='scatter', x='Lat', y='Humidity', marker='o', grid=True,\
                  facecolors='b', edgecolors='k', title=f'City Latitude vs. Humidity ({date})')# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE
plt.grid(False)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE
city_data_df.plot(kind='scatter', x='Lat', y='Cloudiness', marker='o', grid=True,\
                  facecolors='b', edgecolors='k', title=f'City Latitude vs. Cloudiness ({date})')

# Incorporate the other graph properties
# YOUR CODE HERE
plt.grid(False)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE
city_data_df.plot(kind='scatter', x='Lat', y='Wind Speed', marker='o', grid=True,\
                  facecolors='b', edgecolors='k', title=f'City Latitude vs. Wind Speed ({date})')

# Incorporate the other graph properties
# YOUR CODE HERE
plt.grid(False)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.tight_layout()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE
northern_hemi_df = city_data_df.loc[city_data_df['Lat']>= 0,:] 

# Display sample data
northern_hemi_df.head()
# Out:
#                      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                    amga  60.8953  131.9608     15.66        84          71
# 3                  albany  42.6001  -73.9662     18.50        80         100
# 4               iskateley  67.6803   53.1512     10.28        64           8
# 6                qaqortoq  60.7167  -46.0333      8.75        87         100
# 7        puerto armuelles   8.2833  -82.8667     24.99        93         100
#
#          Wind Speed Country                 Date
# City_ID
# 0              2.46      RU  2024-08-07 02:28:52
# 3              1.72      US  2024-08-07 02:22:50
# 4              2.95      RU  2024-08-07 02:33:23
# 6              1.79      GL  2024-08-07 02:33:25
# 7              0.45      PA  2024-08-07 02:33:24

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE
southern_hemi_df = city_data_df.loc[city_data_df['Lat']<= 0,:]

# Display sample data
southern_hemi_df.head()
# Out:
#                              City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 1                      scottburgh -30.2867   30.7532     14.88        74
# 2                       adamstown -25.0660 -130.1015     18.70        66
# 5                    puerto ayora  -0.7393  -90.3518     20.31        91
# 11       sao gabriel da cachoeira  -0.1303  -67.0892     23.86        71
# 15                        betioky -23.7167   44.3833     16.55        92
#
#          Cloudiness  Wind Speed Country                 Date
# City_ID
# 1                 0        2.28      ZA  2024-08-07 02:33:19
# 2                39        5.08      PN  2024-08-07 02:28:51
# 5                82        5.14      EC  2024-08-07 02:23:42
# 11                0        0.53      BR  2024-08-07 02:33:31
# 15                6        4.03      MG  2024-08-07 02:33:37

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE
plt.scatter(northern_hemi_df['Lat'],northern_hemi_df['Max Temp'], marker='o', facecolors='b', edgecolors='k')

# Incorporate the other graph properties
plt.grid(False)
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.title("Latitude vs. Temperature in Northern Hemisphere")

# Define a function to create Linear Regression plots
def lr_funcV2(x,y,name,vbl,hemi):
    (slope,intercept,rvalue,pvalue,stderror)=linregress(x,y)
    reg_values= x*slope + intercept
    plt.plot(x,reg_values,color='r')
    plt.title(f'Latitude vs. {vbl} - {hemi}')
    plt.xlabel('Latitude')
    plt.ylabel(vbl)
    line_eq = f'y = {(round(slope,2))}x + {(round(intercept,2))}'
    print(f'Linear equation: {line_eq}')
    plt.savefig(f"output_data/LinearRegresion_{name}.png")
    print(f'The r-value is: {rvalue}')

x = northern_hemi_df['Lat']
y = northern_hemi_df['Max Temp']
name = 'NH_LatVsMaxTemp'
vbl = 'Maximum Temperature C°'
hemi = 'Northern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()
# Out:
# Linear equation: y = -0.24x + 31.27
# The r-value is: -0.6750845815050336

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE

# Linear regression on Southern Hemisphere
plt.scatter(southern_hemi_df['Lat'],southern_hemi_df['Max Temp'], marker='o', facecolors='b', edgecolors='k')

# Incorporate the other graph properties
plt.grid(False)

slope, intercept, r_value, p_value, std_err = linregress(x, y)
    
reg_line = slope * x + intercept
equation_text = f'y = {slope:.2f}x + {intercept:.2f}'
plt.text(0.5, 0.1, equation_text, transform=plt.gca().transAxes, fontsize=12, verticalalignment='center_baseline')


x = southern_hemi_df['Lat']
y = southern_hemi_df['Max Temp']
name = 'SH_LatVsMaxTemp'
vbl = 'Maximum Temperature C°'
hemi = 'Southern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)

plt.show()
# Out:
# Linear equation: y = 0.43x + 26.95
# The r-value is: 0.7634224048298006

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
plt.scatter(northern_hemi_df['Lat'],northern_hemi_df['Humidity'], marker='o', facecolors='b', edgecolors='k')
plt.grid(False)
x = northern_hemi_df['Lat']
y = northern_hemi_df['Humidity']
name = 'NH_LatVsHumidity'
vbl = 'Humidity (%)'
hemi = 'Northern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)

reg_line = slope * x + intercept
equation_text = f'y = {slope:.2f}x + {intercept:.2f}'
plt.text(0.05, 0.05, equation_text, transform=plt.gca().transAxes, fontsize=20, color='red', horizontalalignment='left', verticalalignment='bottom')
plt.figure(figsize=(1, 1))
plt.show()
# Out:
# Linear equation: y = -0.15x + 77.18
# The r-value is: -0.13777528077842563

# %%
# Southern Hemisphere
plt.scatter(southern_hemi_df['Lat'],southern_hemi_df['Humidity'], marker='o', facecolors='b', edgecolors='k')
# YOUR CODE HERE
plt.grid(False)
x = southern_hemi_df['Lat']
y = southern_hemi_df['Humidity']
name = 'SH_LatVsHumidity'
vbl = 'Humidity (%)'
hemi = 'Southern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()
# Out:
# Linear equation: y = 0.09x + 72.34
# The r-value is: 0.06221866179993647

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
plt.scatter(northern_hemi_df['Lat'],northern_hemi_df['Cloudiness'], marker='o', facecolors='b', edgecolors='k')

# Incorporate the other graph properties
plt.grid(False)

# Linear regression on Northern Hemisphere
x = northern_hemi_df['Lat']
y = northern_hemi_df['Cloudiness']
name = 'NH_LatVsCloudiness'
vbl = 'Cloudiness (%)'
hemi = 'Northern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()
# Out:
# Linear equation: y = -0.36x + 68.3
# The r-value is: -0.17376777472200852

# %%
# Southern Hemisphere
# YOUR CODE HERE
plt.scatter(southern_hemi_df['Lat'],southern_hemi_df['Cloudiness'], marker='o', facecolors='b', edgecolors='k')


plt.grid(False)
x = southern_hemi_df['Lat']
y = southern_hemi_df['Cloudiness']
name = 'SH_LatVsCloudiness'
vbl = 'Cloudiness (%)'
hemi = 'Southern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()
# Out:
# Linear equation: y = -0.13x + 40.83
# The r-value is: -0.04336057762468152

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE
plt.scatter(northern_hemi_df['Lat'],northern_hemi_df['Wind Speed'], marker='o', facecolors='b', edgecolors='k')

plt.grid(False)

x = northern_hemi_df['Lat']
y = northern_hemi_df['Wind Speed']
name = 'NH_LatVsWindSpeed'
vbl = 'Wind Speed (m/s)'
hemi = 'Northern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()
# Out:
# Linear equation: y = -0.0x + 3.41
# The r-value is: -0.02481511896235977

# %%
# Southern Hemisphere
# YOUR CODE HERE
plt.scatter(southern_hemi_df['Lat'],southern_hemi_df['Wind Speed'], marker='o', facecolors='b', edgecolors='k')

plt.grid(False)

x = southern_hemi_df['Lat']
y = southern_hemi_df['Wind Speed']
name = 'SH_LatVsWindSpeed'
vbl = 'Wind Speed (m/s)'
hemi = 'Southern Hemisphere'
lr_funcV2(x,y,name,vbl,hemi)
plt.show()
# Out:
# Linear equation: y = 0.02x + 3.89
# The r-value is: 0.08314831603190799

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
